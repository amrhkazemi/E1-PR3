# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/linearR.xlsx')

# %%
df.head()
# Out:
#    input1  input2  input3  output
# 0     740     724     739     727
# 1     724     739     727     743
# 2     739     727     743     736
# 3     727     743     736     725
# 4     743     736     725     731

# %%
df_x0=df[['input1','input2','input3']]
df_x1=df[['input1']]
df_x2=df[['input2']]
df_x3=df[['input3']]
df_y=df[['output']]

# %%
plt.plot(df_x1,df_y,'o')

# %%
plt.plot(df_x2,df_y,'o')

# %%
plt.plot(df_x3,df_y,'o')

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(df_x0,df_y)
# Out:
# LinearRegression()

# %%
print(model.coef_,model.intercept_)
# Out:
# [[0.29122845 0.42817241 0.4656458 ]] [-130.99841973]

# %%
yhat=model.predict(df_x0)

# %%
plt.scatter(df_y,yhat)

# %%
plt.scatter(df_x1,yhat)

# %%
plt.scatter(df_x2,yhat)

# %%
plt.scatter(df_x3,yhat)
